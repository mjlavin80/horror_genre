# %%
import sqlite3
from scipy import signal, stats
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (11, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
conn = sqlite3.connect('gl_ratios.db')
c = conn.cursor()
rows = c.execute("""SELECT gl_ratio_no_set, year FROM results 
    WHERE genre='all_genres' and no_data=0 and too_short=0""").fetchall()
poetry = c.execute("""SELECT gl_ratio_no_set, year FROM results 
    WHERE genre='poetry' and no_data=0 and too_short=0""").fetchall()
fiction = c.execute("""SELECT gl_ratio_no_set, year FROM results 
    WHERE genre='fiction' and no_data=0 and too_short=0""").fetchall()
nonfiction = c.execute("""SELECT gl_ratio_no_set, year FROM results 
    WHERE genre='nonfiction' and no_data=0 and too_short=0""").fetchall()
drama = c.execute("""SELECT gl_ratio_no_set, year FROM results 
    WHERE genre='drama' and no_data=0 and too_short=0""").fetchall()

# %%
y = [i[0] for i in rows] 
x = [i[1] for i in rows]
plt.title("Germanic/Latinate Ratios by Year", fontsize=28,  y=1.08) 
plt.scatter(x,y, c='b', marker="s",)

# %%
y_1 = [i[0] for i in poetry] 
x_1 = [i[1] for i in poetry]
y_2 = [i[0] for i in fiction] 
x_2 = [i[1] for i in fiction]
y_3 = [i[0] for i in nonfiction]
x_3 = [i[1] for i in nonfiction]
y_4 = [i[0] for i in drama]
x_4 = [i[1] for i in drama]
y_1_sav = signal.savgol_filter(y_1, 51, 3) # window size 51, polynomial order 3
y_2_sav = signal.savgol_filter(y_2, 51, 3)
y_3_sav = signal.savgol_filter(y_3, 51, 3)
y_4_sav = signal.savgol_filter(y_4, 51, 3)

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x_1, y_1, s=5, c='b', marker="o", label='poetry')
ax1.scatter(x_2,y_2, s=5, c='r', marker="o", label='fiction')
ax1.scatter(x_3,y_3, s=5, c='g', marker="o", label='nonfiction')
ax1.scatter(x_4,y_4, s=5, c='orange', marker="o", label='drama')
plt.title("Germanic/Latinate Ratios by Year, Subdivided by Genre", fontsize=28, y=1.08)
plt.plot(x_1, y_1_sav, linewidth=3.0, c="b")
plt.plot(x_2, y_2_sav, linewidth=3.0, c="r")
plt.plot(x_3, y_3_sav, linewidth=3.0, c="g")
plt.plot(x_4, y_4_sav, linewidth=3.0, c="orange")
plt.legend(loc='upper left');
plt.show()

# %%
poetry = c.execute("""SELECT gl_ratio_set, year FROM results 
    WHERE genre='poetry' and no_data=0 and too_short=0""").fetchall()
fiction = c.execute("""SELECT gl_ratio_set, year FROM results 
    WHERE genre='fiction' and no_data=0 and too_short=0""").fetchall()
nonfiction = c.execute("""SELECT gl_ratio_set, year FROM results 
    WHERE genre='nonfiction' and no_data=0 and too_short=0""").fetchall()
drama = c.execute("""SELECT gl_ratio_set, year FROM results 
    WHERE genre='drama' and no_data=0 and too_short=0""").fetchall()
y_1 = [i[0] for i in poetry] 
x_1 = [i[1] for i in poetry]
y_2 = [i[0] for i in fiction] 
x_2 = [i[1] for i in fiction]
y_3 = [i[0] for i in nonfiction]
x_3 = [i[1] for i in nonfiction]
y_4 = [i[0] for i in drama]
x_4 = [i[1] for i in drama]
y_1_sav = signal.savgol_filter(y_1, 51, 3) # window size 51, polynomial order 3
y_2_sav = signal.savgol_filter(y_2, 51, 3)
y_3_sav = signal.savgol_filter(y_3, 51, 3)
y_4_sav = signal.savgol_filter(y_4, 51, 3)

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x_1, y_1, s=5, c='b', marker="o", label='poetry')
ax1.scatter(x_2,y_2, s=5, c='r', marker="o", label='fiction')
ax1.scatter(x_3,y_3, s=5, c='g', marker="o", label='nonfiction')
ax1.scatter(x_4,y_4, s=5, c='orange', marker="o", label='drama')
plt.title("Germanic/Latinate Ratios by Year and Genre, with Each Term Counted Once Per Year", fontsize=28, y=1.08)
plt.plot(x_1, y_1_sav, linewidth=3.0, c="b")
plt.plot(x_2, y_2_sav, linewidth=3.0, c="r")
plt.plot(x_3, y_3_sav, linewidth=3.0, c="g")
plt.plot(x_4, y_4_sav, linewidth=3.0, c="orange")
plt.legend(loc='upper left');
plt.show()

# %%
poetry = c.execute("""SELECT tt_ratio, year FROM results 
    WHERE genre='poetry' and no_data=0 and too_short=0""").fetchall()
fiction = c.execute("""SELECT tt_ratio, year FROM results 
    WHERE genre='fiction' and no_data=0 and too_short=0""").fetchall()
nonfiction = c.execute("""SELECT tt_ratio, year FROM results 
    WHERE genre='nonfiction' and no_data=0 and too_short=0""").fetchall()
drama = c.execute("""SELECT tt_ratio, year FROM results 
    WHERE genre='drama' and no_data=0 and too_short=0""").fetchall()
y_1 = [i[0] for i in poetry] 
x_1 = [i[1] for i in poetry]
y_2 = [i[0] for i in fiction] 
x_2 = [i[1] for i in fiction]
y_3 = [i[0] for i in nonfiction]
x_3 = [i[1] for i in nonfiction]
y_4 = [i[0] for i in drama]
x_4 = [i[1] for i in drama]
y_1_sav = signal.savgol_filter(y_1, 51, 3) # window size 51, polynomial order 3
y_2_sav = signal.savgol_filter(y_2, 51, 3)
y_3_sav = signal.savgol_filter(y_3, 51, 3)
y_4_sav = signal.savgol_filter(y_4, 51, 3)

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x_1, y_1, s=5, c='b', marker="o", label='poetry')
ax1.scatter(x_2,y_2, s=5, c='r', marker="o", label='fiction')
ax1.scatter(x_3,y_3, s=5, c='g', marker="o", label='nonfiction')
ax1.scatter(x_4,y_4, s=5, c='orange', marker="o", label='drama')
plt.title("Type-Token Ratios by Year", fontsize=28,  y=1.08)
plt.plot(x_1, y_1_sav, linewidth=3.0, c="b")
plt.plot(x_2, y_2_sav, linewidth=3.0, c="r")
plt.plot(x_3, y_3_sav, linewidth=3.0, c="g")
plt.plot(x_4, y_4_sav, linewidth=3.0, c="orange")
plt.legend(loc='upper left');
plt.show()

# %%
import json
poetry_json = c.execute("""SELECT gl_resample_no_set, year FROM results 
    WHERE genre='poetry' and no_data=0 and too_short=0""").fetchall()
fiction_json = c.execute("""SELECT gl_resample_no_set, year 
    FROM results WHERE genre='fiction' and no_data=0 and too_short=0""").fetchall()
nonfiction_json = c.execute("""SELECT gl_resample_no_set, year FROM results 
    WHERE genre='nonfiction' and no_data=0 and too_short=0""").fetchall()
drama_json = c.execute("""SELECT gl_resample_no_set, year 
    FROM results WHERE genre='drama' and no_data=0 and too_short=0""").fetchall()

# %%
p = [json.loads(i[0]) for i in poetry_json]
f = [json.loads(i[0]) for i in fiction_json]
n= [json.loads(i[0]) for i in nonfiction_json]
d = [json.loads(i[0]) for i in drama_json]

y_1 = [sum(i)/len(i) for i in p]
y_2 = [sum(i)/len(i) for i in f]
y_3 = [sum(i)/len(i) for i in n]
y_4 = [sum(i)/len(i) for i in d]

x_1 = [i[1] for i in poetry_json]
x_2 = [i[1] for i in fiction_json]
x_3 = [i[1] for i in nonfiction_json]
x_4 = [i[1] for i in drama_json]

y_1_sav = signal.savgol_filter(y_1, 51, 3) # window size 51, polynomial order 3
y_2_sav = signal.savgol_filter(y_2, 51, 3)
y_3_sav = signal.savgol_filter(y_3, 51, 3)
y_4_sav = signal.savgol_filter(y_4, 51, 3)

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x_1, y_1, s=5, c='b', marker="o", label='poetry')
ax1.scatter(x_2,y_2, s=5, c='r', marker="o", label='fiction')
ax1.scatter(x_3,y_3, s=5, c='g', marker="o", label='nonfiction')
ax1.scatter(x_4,y_4, s=5, c='orange', marker="o", label='drama')
plt.title("Germanic/Latinate Ratios by Year and Genre after 5k-word Resampling", fontsize=28,  y=1.08)
plt.plot(x_1, y_1_sav, linewidth=3.0, c="b")
plt.plot(x_2, y_2_sav, linewidth=3.0, c="r")
plt.plot(x_3, y_3_sav, linewidth=3.0, c="g")
plt.plot(x_4, y_4_sav, linewidth=3.0, c="orange")

plt.legend(loc='upper left');
plt.show()

# %%
std_p = [np.std(i) for i in p] 
std_f = [np.std(i) for i in f]
std_n = [np.std(i) for i in n]
std_d = [np.std(i) for i in d]

plt.title("Germanic/Latinate Ratios by Year and Genre, Savitzky-Golay vs. Actual +- Std", fontsize=28,  y=1.08)
plt.fill_between(x_1, np.asarray(y_1)-std_p, np.asarray(y_1)+std_p,facecolor='b',alpha=0.35)
plt.fill_between(x_2, np.asarray(y_2)-std_f, np.asarray(y_2)+std_f,facecolor='r',alpha=0.35)
plt.fill_between(x_3, np.asarray(y_3)-std_n, np.asarray(y_3)+std_n,facecolor='g',alpha=0.35)

plt.plot(x_1, y_1_sav, linewidth=3.0, c="b")
plt.plot(x_2, y_2_sav, linewidth=3.0, c="r")
plt.plot(x_3, y_3_sav, linewidth=3.0, c="g")

plt.show()

# %%
import ast
def neo_ratio(data_rows):
    ratios = []
    for i in data_rows:
        _dict = ast.literal_eval(i[1])
        ratio = _dict["neo_no_set"]/float(i[0])
        ratios.append(ratio)
    return ratios

conn = sqlite3.connect('gl_ratios.db')
c = conn.cursor()
rows = c.execute("""SELECT original_length, dictcom_matches, year FROM results 
    WHERE genre='all_genres' and no_data=0 and too_short=0""").fetchall()
poetry = c.execute("""SELECT original_length, dictcom_matches, year FROM results 
    WHERE genre='poetry' and no_data=0 and too_short=0""").fetchall()
fiction = c.execute("""SELECT original_length, dictcom_matches, year FROM results 
    WHERE genre='fiction' and no_data=0 and too_short=0""").fetchall()
nonfiction = c.execute("""SELECT original_length, dictcom_matches, year FROM results 
    WHERE genre='nonfiction' and no_data=0 and too_short=0""").fetchall()
drama = c.execute("""SELECT original_length, dictcom_matches, year FROM results 
    WHERE genre='drama' and no_data=0 and too_short=0""").fetchall()

y_1 = neo_ratio(poetry) 
x_1 = [i[2] for i in poetry]

y_2 = neo_ratio(fiction) 
x_2 = [i[2] for i in fiction]
y_3 = neo_ratio(nonfiction)
x_3 = [i[2] for i in nonfiction]
y_4 = neo_ratio(drama)
x_4 = [i[2] for i in drama]
y_1_sav = signal.savgol_filter(y_1, 51, 3) # window size 51, polynomial order 3
y_2_sav = signal.savgol_filter(y_2, 51, 3)
y_3_sav = signal.savgol_filter(y_3, 51, 3)
y_4_sav = signal.savgol_filter(y_4, 51, 3)

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x_1, y_1, s=5, c='b', marker="o", label='poetry')
ax1.scatter(x_2,y_2, s=5, c='r', marker="o", label='fiction')
ax1.scatter(x_3,y_3, s=5, c='g', marker="o", label='nonfiction')
ax1.scatter(x_4,y_4, s=5, c='orange', marker="o", label='drama')
plt.title("Post 1700 Neologisms", fontsize=28,  y=1.08)
plt.plot(x_1, y_1_sav, linewidth=3.0, c="b")
plt.plot(x_2, y_2_sav, linewidth=3.0, c="r")
plt.plot(x_3, y_3_sav, linewidth=3.0, c="g")
plt.plot(x_4, y_4_sav, linewidth=3.0, c="orange")
plt.legend(loc='upper left');
plt.show()
